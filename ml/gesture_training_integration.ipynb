# %%
# Install requirements if not already installed (uncomment to run).
# Note: TensorFlow is optional and can be large; only install if you intend to train/export TFLite.
# !python -m pip install -r ml/requirements.txt
# !python -m pip install tensorflow  # optional for TF/TFLite export
print('Skip automatic install in this demo cell — run manually if needed')
: 
,
: {
: 

: [
,

# %% [markdown]
# ## Notes and next steps
#
# - You can re-run the training cell with `--model-type tf` and `--export-tflite` if TensorFlow is installed to create a TFLite model and a C header for firmware embedding.
# - If you want I can: integrate these cells back into `gesture_training.ipynb`, add interactive widgets for augmentation params, or implement an automated flow to copy the generated header into `ml/gesture_model_data.h`.
